# %% [markdown]
# <a href="https://colab.research.google.com/github/araya1203/toy_pythons/blob/main/C_LoopWithCounter_ARAJO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
count=1

# %%
while count < 6 :
 print(count)
 count = count + 1
print('End')
# Out:
# 1
# 2
# 3
# 4
# 5
# End
