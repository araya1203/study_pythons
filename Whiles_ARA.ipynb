# %% [markdown]
# <a href="https://colab.research.google.com/github/araya1203/toy_pythons/blob/main/Whiles_ARA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
first = 1

# %%
while first < 4 :
  print(first)
  print('in whiling')
  first = first + 1
print('End')
# Out:
# End
